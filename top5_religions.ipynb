# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stb

edu_countries = pd.read_excel("EdStatsCountry.xls")
edu_countries_series = pd.read_excel("EdStatsCountry-Series.xls")
edu_data2 = pd.read_csv("EdStatsData.csv")
edu_footnote = pd.read_excel("EdStatsFootNote.xls")
edu_series = pd.read_excel("EdStatsSeries.xls")

religion_global = pd.read_excel("global.xls")
religion_national = pd.read_excel("national.xls")
religion_regional = pd.read_excel("regional.xls")

# %%
religion_national.columns
# Out:
# Index(['year', 'state', 'code', 'christianity_protestant',
#        'christianity_romancatholic', 'christianity_easternorthodox',
#        'christianity_anglican', 'christianity_other', 'christianity_all',
#        'judaism_orthodox', 'judaism_conservative', 'judaism_reform',
#        'judaism_other', 'judaism_all', 'islam_sunni', 'islam_shi’a',
#        'islam_ibadhi', 'islam_nationofislam', 'islam_alawite',
#        'islam_ahmadiyya', 'islam_other', 'islam_all', 'buddhism_mahayana',
#        'buddhism_theravada', 'buddhism_other', 'buddhism_all',
#        'zoroastrianism_all', 'hinduism_all', 'sikhism_all', 'shinto_all',
#        'baha’i_all', 'taoism_all', 'jainism_all', 'confucianism_all',
#        'syncretism_all', 'animism_all', 'noreligion_all', 'otherreligion_all',
#        'religion_all', 'population', 'protestant_percent',
#        'romancatholic_percent', 'easternorthodox_percent', 'anglican_percent',
# ...

# %%
plot_data1 = religion_national[religion_national.year==2010][['state', 'christianity_all']].sort_values(by='christianity_all', ascending=False)
plot_data1

plot_data2 = religion_national[religion_national.year==2010][['state','judaism_all']].sort_values(by='judaism_all', ascending=False)[:20]
plot_data2

plot_data3 = religion_national[religion_national.year==2010][['state','islam_all']].sort_values(by='islam_all', ascending=False)[:20]
plot_data3

plot_data4 = religion_national[religion_national.year==2010][['state', 'buddhism_all']].sort_values(by='buddhism_all', ascending=False)[:20]
plot_data4

plot_data5 = religion_national[religion_national.year==2010][['state', 'hinduism_all']].sort_values(by='hinduism_all', ascending=False)[:20]
plot_data5
# Out:
#                          state  hinduism_all
# 1719                     India     961401054
# 1798                     Nepal      21551492
# 1748                Bangladesh      13256161
# 1740                  Pakistan       3705824
# 1903                 Indonesia       3599400
# 1774                 Sri Lanka       2565831
# 13    United States of America       1797698
# 1863                  Malaysia       1698000
# 1582      United Arab Emirates       1387654
# 426             United Kingdom        817000
# 1275              South Africa        750331
# 1335                 Mauritius        622238
# 1573                     Qatar        450000
# 1159                  Tanzania        322500
# 27                      Canada        275000
# 1524              Saudi Arabia        260907
# 1873                 Singapore        258053
# 1969                      Fiji        240609
# 99         Trinidad and Tobago        240100
# 292                     Guyana        226412

# %%
plt.figure(figsize=[25, 6])

plt.bar(x=plot_data4['state'][:10], height=plot_data4['buddhism_all'][:10])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=[25, 6])

plt.bar(x=plot_data5['state'][:10], height=plot_data5['hinduism_all'][:10])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=[25, 6])

plt.bar(x=plot_data2['state'][:10], height=plot_data2['judaism_all'][:10])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=[25, 6])

plt.bar(x=plot_data1['state'][:10], height=plot_data1['christianity_all'][:10])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=[20, 6])

plt.bar(x=plot_data3['state'][:10], height=plot_data3['islam_all'][:10])
# Out:
# <BarContainer object of 10 artists>
